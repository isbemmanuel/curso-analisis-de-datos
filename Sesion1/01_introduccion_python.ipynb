# %% [markdown]
# ## Comentarios
# seccion para lectura o escritura de comentarios

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
"""
    linea 1
    linea 2
    linea3 
"""

# %% [markdown]
# Diccionario

# %%
my_dic={
    1:"apple",
    2:"pera"
}

print(my_dic)
# Out:
# {1: 'apple', 2: 'pera'}
